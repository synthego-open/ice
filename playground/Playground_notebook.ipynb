# %%
import glob
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import matplotlib as mpl
import scipy as sp
import itertools
from collections import defaultdict
import seaborn as sns
import glob
import json
from bs4 import BeautifulSoup
import codecs
import sys
from Bio import SeqIO, pairwise2, Seq

# %%
ice_dpth = '../data/ICE/v1_2/'
ngs_dpth = 'data/NGS/'
tide_pth = 'data/TIDE/tide_output/'

# %% [markdown]
# # Helper Functions

# %%
### 

def get_efficiency(text):
    parse_str = 'overall efficiency = '
    start = text.find(parse_str) + len(parse_str)
    end = start+4
    
    return float(text[start:end])

def get_r2(text):
    parse_str = 'R² = '
    start = text.find(parse_str) + len(parse_str)
    end = start+4
    
    return float(text[start:end])

def get_indels(text):
    start_str = '\npercentage\npvalue'
    end_str = '\n×\nSave Experiment'
    start = text.find(start_str) + len(start_str)
    end = text.find(end_str)
    garbage = text[start:end]
    
    counter = 0
    size, freq, p = [],[],[]
    for line in garbage.split('\n'):
        if len(line):
            if np.mod(counter,3) == 0:
                size.append(line)
            elif np.mod(counter,3) == 1:
                freq.append(float(line))
            elif np.mod(counter,3) == 2:
                p.append(float(line))
            counter+=1
            
    return size,freq

def simple_length_counting(fname):
    ref_len = 0
    histogram = defaultdict(int)

    for record in SeqIO.parse(fname, "fasta"):
        split_header = record.description.split(",")
        if len(split_header)> 1:
            percentage = float(split_header[1].strip()[:-1])
            indel =   len(record.seq) - ref_len
            histogram[indel] += percentage
        else:
            #wt reference
            ref_len = len(record.seq)
            #print("wt is ", record.name)
    if ref_len == 0:
        print("ERROR", fname)
    return histogram, ref_len

# %% [markdown]
# # Import All Data

# %%
htmls = glob.glob(tide_pth + '*.htm')
labels = [s.split('/')[-1] for s in htmls]
tide_edits = pd.DataFrame(index = labels, columns = ['efficiency','r2'])
tide_indels = pd.DataFrame(index = labels, columns = np.arange(-10,11).astype('str'))
for hpth in htmls:
    hname = hpth.split('/')[-1]
    #open html
    f=codecs.open(hpth, 'r')
    
    #parse it w/ bs
    soup = BeautifulSoup(f, 'html.parser')
    for script in soup(["script", "style"]):
        script.extract()    # rip it out

    # get text
    text = soup.get_text()
    
    if '\nError\nError' in text:
        continue
    
    tide_edits.loc[hname,'efficiency'] = get_efficiency(text)
    tide_edits.loc[hname,'r2'] = get_r2(text)
    sizes,freqs = get_indels(text)
    tide_indels.loc[hname,np.arange(-10,11).astype('str')] = freqs
tide_indels = tide_indels.astype("float")
tide_indels = tide_indels.reindex( tide_indels.columns.tolist() + list(np.arange(-30,-10).astype("str")),axis=1)
tide_indels.loc[:,np.arange(-30,-10).astype("str")] = 0

# %%
#Get NGS data
files = glob.glob(ngs_dpth+"*.seq")
ngs = pd.DataFrame()
for f in files:
    indel = pd.Series(0,index=np.arange(-30,15))
    indel.update(pd.Series(simple_length_counting(f)[0]))
    indel['position'] = f.split('/')[-1].split('_')[0]
    #indel.name = f.split('/')[-1].split('_')[0]
    ngs = ngs.append(indel,ignore_index=True)

# %%
glob.glob(tide_pth + '*.htm')
# Out:
# ['data/TIDE/tide_output/posF1_PANK2_1_B;PANK2_R_0.htm',
#  'data/TIDE/tide_output/posD6_STK4_2_A;STK4_R_0.htm',
#  'data/TIDE/tide_output/posH1_RET_1_B;RET_R_0.htm',
#  'data/TIDE/tide_output/posG6_CHUK_2_A;CHUK_R_0.htm',
#  'data/TIDE/tide_output/posA1_RYK_1_B;RYK_R_0.htm',
#  'data/TIDE/tide_output/posD5_STK3_2_B;STK3_R_0.htm',
#  'data/TIDE/tide_output/posE8_MYO3A_3_B;MYO3A_R_0.htm',
#  'data/TIDE/tide_output/posF4_PANK2_2_A;PANK2_R_0.htm',
#  'data/TIDE/tide_output/posG9_CHUK_3_B;CHUK_R_0.htm',
#  'data/TIDE/tide_output/posG8_UCK2_3_A;UCK2_R_0.htm',
#  'data/TIDE/tide_output/posD9_STK4_3_B;STK4_R_0.htm',
#  'data/TIDE/tide_output/posA4_RYK_2_B;RYK_R_0.htm',
#  'data/TIDE/tide_output/posH4_RET_2_B;RET_R_0.htm',
#  'data/TIDE/tide_output/posC5_PRKAG3_2_A;PRKAG3_R_0.htm',
#  'data/TIDE/tide_output/posB2_PIK3CA_1_B;PIK3CA_R_0.htm',
#  'data/TIDE/tide_output/posB9_PIK3CB_3_A;PIK3CB_R_0.htm',
#  'data/TIDE/tide_output/posC9_IRAK4_3_B;IRAK4_R_0.htm',
#  'data/TIDE/tide_output/posF7_PANK2_3_A;PANK2_R_0.htm',
#  'data/TIDE/tide_output/posH8_SBK2_3_A;SBK2_R_0.htm',
#  'data/TIDE/tide_output/posF5_TTK_2_B;TTK_R_0.htm',
#  'data/TIDE/tide_output/posD8_STK3_3_A;STK3_R_0.htm',
#  'data/TIDE/tide_output/posF2_TTK_1_B;TTK_R_0.htm',
#  'data/TIDE/tide_output/posG5_UCK2_2_B;UCK2_R_0.htm',
#  'data/TIDE/tide_output/posC9_IRAK4_3_A;IRAK4_R_0.htm',
#  'data/TIDE/tide_output/posC8_PRKAG3_3_A;PRKAG3_R_0.htm',
#  'data/TIDE/tide_output/posF7_PANK2_3_B;PANK2_R_0.htm',
#  'data/TIDE/tide_output/posB6_PIK3CB_2_B;PIK3CB_R_0.htm',
#  'data/TIDE/tide_output/posF1_PANK2_1_A;PANK2_R_0.htm',
#  'data/TIDE/tide_output/posA3_PRKAG1_1_B;PRKAG1_R_0.htm',
#  'data/TIDE/tide_output/posD1_PIK3C2A_1_A;PIK3C2A_R_0.htm',
#  'data/TIDE/tide_output/posH5_SBK2_2_B;SBK2_R_0.htm',
#  'data/TIDE/tide_output/posF4_PANK2_2_B;PANK2_R_0.htm',
#  'data/TIDE/tide_output/posG4_UCK1_2_B;UCK1_R_0.htm',
#  'data/TIDE/tide_output/posE8_MYO3A_3_A;MYO3A_R_0.htm',
#  'data/TIDE/tide_output/posD7_PIK3C2A_3_B;PIK3C2A_R_0.htm',
#  'data/TIDE/tide_output/posC6_IRAK4_2_A;IRAK4_R_0.htm',
#  'data/TIDE/tide_output/posG3_CHUK_1_B;CHUK_R_0.htm',
#  'data/TIDE/tide_output/posD4_PIK3C2A_2_A;PIK3C2A_R_0.htm',
#  'data/TIDE/tide_output/posD3_STK4_1_B;STK4_R_0.htm',
#  'data/TIDE/tide_output/posG2_UCK2_1_A;UCK2_R_0.htm',
#  'data/TIDE/tide_output/posC3_IRAK4_1_B;IRAK4_R_0.htm',
#  'data/TIDE/tide_output/posB9_PIK3CB_3_B;PIK3CB_R_0.htm',
#  'data/TIDE/tide_output/posH2_SBK2_1_A;SBK2_R_0.htm',
#  'data/TIDE/tide_output/posB2_PIK3CA_1_A;PIK3CA_R_0.htm',
#  'data/TIDE/tide_output/posC5_PRKAG3_2_B;PRKAG3_R_0.htm',
#  'data/TIDE/tide_output/posE2_MYO3A_1_B;MYO3A_R_0.htm',
#  'data/TIDE/tide_output/posA5_BUB1B_2_A;BUB1B_R_0.htm',
#  'data/TIDE/tide_output/posF5_TTK_2_A;TTK_R_0.htm',
#  'data/TIDE/tide_output/posF2_TTK_1_A;TTK_R_0.htm',
#  'data/TIDE/tide_output/posC8_PRKAG3_3_B;PRKAG3_R_0.htm',
#  'data/TIDE/tide_output/posB6_PIK3CB_2_A;PIK3CB_R_0.htm',
#  'data/TIDE/tide_output/posD2_STK3_1_A;STK3_R_0.htm',
#  'data/TIDE/tide_output/posE2_MYO3A_1_A;MYO3A_R_0.htm',
#  'data/TIDE/tide_output/posA5_BUB1B_2_B;BUB1B_R_0.htm',
#  'data/TIDE/tide_output/posH4_RET_2_A;RET_R_0.htm',
#  'data/TIDE/tide_output/posA4_RYK_2_A;RYK_R_0.htm',
#  'data/TIDE/tide_output/posG7_UCK1_3_A;UCK1_R_0.htm',
#  'data/TIDE/tide_output/posC6_IRAK4_2_B;IRAK4_R_0.htm',
#  'data/TIDE/tide_output/posA1_RYK_1_A;RYK_R_0.htm',
#  'data/TIDE/tide_output/posC3_IRAK4_1_A;IRAK4_R_0.htm',
#  'data/TIDE/tide_output/posH1_RET_1_A;RET_R_0.htm',
#  'data/TIDE/tide_output/posG1_UCK1_1_A;UCK1_R_0.htm',
#  'data/TIDE/tide_output/posA3_PRKAG1_1_A;PRKAG1_R_0.htm',
#  'data/TIDE/tide_output/posB3_PIK3CB_1_B;PIK3CB_R_0.htm',
#  'data/TIDE/tide_output/posE9_MYO3B_3_B;MYO3B_R_0.htm',
#  'data/TIDE/tide_output/posD3_STK4_1_A;STK4_R_0.htm',
#  'data/TIDE/tide_output/posG2_UCK2_1_B;UCK2_R_0.htm',
#  'data/TIDE/tide_output/posB8_PIK3CA_3_A;PIK3CA_R_0.htm',
#  'data/TIDE/tide_output/posG3_CHUK_1_A;CHUK_R_0.htm',
#  'data/TIDE/tide_output/posD7_PIK3C2A_3_A;PIK3C2A_R_0.htm',
#  'data/TIDE/tide_output/posD1_PIK3C2A_1_B;PIK3C2A_R_0.htm',
#  'data/TIDE/tide_output/posH2_SBK2_1_B;SBK2_R_0.htm',
#  'data/TIDE/tide_output/posE5_MYO3A_2_A;MYO3A_R_0.htm',
#  'data/TIDE/tide_output/posA2_BUB1B_1_B;BUB1B_R_0.htm',
#  'data/TIDE/tide_output/posA6_PRKAG1_2_B;PRKAG1_R_0.htm',
#  'data/TIDE/tide_output/posA7_RYK_3_A;RYK_R_0.htm',
#  'data/TIDE/tide_output/posH7_RET_3_A;RET_R_0.htm',
#  'data/TIDE/tide_output/posD2_STK3_1_B;STK3_R_0.htm',
#  'data/TIDE/tide_output/posA9_PRKAG1_3_A;PRKAG1_R_0.htm',
#  'data/TIDE/tide_output/posA2_BUB1B_1_A;BUB1B_R_0.htm',
#  'data/TIDE/tide_output/posG1_UCK1_1_B;UCK1_R_0.htm',
#  'data/TIDE/tide_output/posE9_MYO3B_3_A;MYO3B_R_0.htm',
#  'data/TIDE/tide_output/posF8_TTK_3_B;TTK_R_0.htm',
#  'data/TIDE/tide_output/posC2_PRKAG3_1_B;PRKAG3_R_0.htm',
#  'data/TIDE/tide_output/posB5_PIK3CA_2_A;PIK3CA_R_0.htm',
#  'data/TIDE/tide_output/posG7_UCK1_3_B;UCK1_R_0.htm',
#  'data/TIDE/tide_output/posB8_PIK3CA_3_B;PIK3CA_R_0.htm',
#  'data/TIDE/tide_output/posG8_UCK2_3_B;UCK2_R_0.htm',
#  'data/TIDE/tide_output/posD9_STK4_3_A;STK4_R_0.htm',
#  'data/TIDE/tide_output/posG9_CHUK_3_A;CHUK_R_0.htm',
#  'data/TIDE/tide_output/posG6_CHUK_2_B;CHUK_R_0.htm',
#  'data/TIDE/tide_output/posD5_STK3_2_A;STK3_R_0.htm',
#  'data/TIDE/tide_output/posB3_PIK3CB_1_A;PIK3CB_R_0.htm',
#  'data/TIDE/tide_output/posB7_CAMK1_3_B;CAMK1_R_0.htm',
#  'data/TIDE/tide_output/posF8_TTK_3_A;TTK_R_0.htm',
#  'data/TIDE/tide_output/posD6_STK4_2_B;STK4_R_0.htm',
#  'data/TIDE/tide_output/posA8_BUB1B_3_B;BUB1B_R_0.htm',
#  'data/TIDE/tide_output/posA6_PRKAG1_2_A;PRKAG1_R_0.htm',
#  'data/TIDE/tide_output/posB1_CAMK1_1_A;CAMK1_R_0.htm',
#  'data/TIDE/tide_output/posE3_MYO3B_1_B;MYO3B_R_0.htm',
#  'data/TIDE/tide_output/posH8_SBK2_3_B;SBK2_R_0.htm',
#  'data/TIDE/tide_output/posE6_MYO3B_2_A;MYO3B_R_0.htm',
#  'data/TIDE/tide_output/posB4_CAMK1_2_B;CAMK1_R_0.htm',
#  'data/TIDE/tide_output/posE3_MYO3B_1_A;MYO3B_R_0.htm',
#  'data/TIDE/tide_output/posB1_CAMK1_1_B;CAMK1_R_0.htm',
#  'data/TIDE/tide_output/posH7_RET_3_B;RET_R_0.htm',
#  'data/TIDE/tide_output/posA7_RYK_3_B;RYK_R_0.htm',
#  'data/TIDE/tide_output/posG5_UCK2_2_A;UCK2_R_0.htm',
#  'data/TIDE/tide_output/posA9_PRKAG1_3_B;PRKAG1_R_0.htm',
#  'data/TIDE/tide_output/posB4_CAMK1_2_A;CAMK1_R_0.htm',
#  'data/TIDE/tide_output/posE6_MYO3B_2_B;MYO3B_R_0.htm',
#  'data/TIDE/tide_output/posD8_STK3_3_B;STK3_R_0.htm',
#  'data/TIDE/tide_output/posD4_PIK3C2A_2_B;PIK3C2A_R_0.htm',
#  'data/TIDE/tide_output/posH5_SBK2_2_A;SBK2_R_0.htm',
#  'data/TIDE/tide_output/posG4_UCK1_2_A;UCK1_R_0.htm',
#  'data/TIDE/tide_output/posB5_PIK3CA_2_B;PIK3CA_R_0.htm',
#  'data/TIDE/tide_output/posC2_PRKAG3_1_A;PRKAG3_R_0.htm',
#  'data/TIDE/tide_output/posA8_BUB1B_3_A;BUB1B_R_0.htm',
#  'data/TIDE/tide_output/posB7_CAMK1_3_A;CAMK1_R_0.htm']

# %%
glob.glob('data/TIDE/tide_output/*.htm')
# Out:
# ['data/TIDE/tide_output/posF1_PANK2_1_B;PANK2_R_0.htm',
#  'data/TIDE/tide_output/posD6_STK4_2_A;STK4_R_0.htm',
#  'data/TIDE/tide_output/posH1_RET_1_B;RET_R_0.htm',
#  'data/TIDE/tide_output/posG6_CHUK_2_A;CHUK_R_0.htm',
#  'data/TIDE/tide_output/posA1_RYK_1_B;RYK_R_0.htm',
#  'data/TIDE/tide_output/posD5_STK3_2_B;STK3_R_0.htm',
#  'data/TIDE/tide_output/posE8_MYO3A_3_B;MYO3A_R_0.htm',
#  'data/TIDE/tide_output/posF4_PANK2_2_A;PANK2_R_0.htm',
#  'data/TIDE/tide_output/posG9_CHUK_3_B;CHUK_R_0.htm',
#  'data/TIDE/tide_output/posG8_UCK2_3_A;UCK2_R_0.htm',
#  'data/TIDE/tide_output/posD9_STK4_3_B;STK4_R_0.htm',
#  'data/TIDE/tide_output/posA4_RYK_2_B;RYK_R_0.htm',
#  'data/TIDE/tide_output/posH4_RET_2_B;RET_R_0.htm',
#  'data/TIDE/tide_output/posC5_PRKAG3_2_A;PRKAG3_R_0.htm',
#  'data/TIDE/tide_output/posB2_PIK3CA_1_B;PIK3CA_R_0.htm',
#  'data/TIDE/tide_output/posB9_PIK3CB_3_A;PIK3CB_R_0.htm',
#  'data/TIDE/tide_output/posC9_IRAK4_3_B;IRAK4_R_0.htm',
#  'data/TIDE/tide_output/posF7_PANK2_3_A;PANK2_R_0.htm',
#  'data/TIDE/tide_output/posH8_SBK2_3_A;SBK2_R_0.htm',
#  'data/TIDE/tide_output/posF5_TTK_2_B;TTK_R_0.htm',
#  'data/TIDE/tide_output/posD8_STK3_3_A;STK3_R_0.htm',
#  'data/TIDE/tide_output/posF2_TTK_1_B;TTK_R_0.htm',
#  'data/TIDE/tide_output/posG5_UCK2_2_B;UCK2_R_0.htm',
#  'data/TIDE/tide_output/posC9_IRAK4_3_A;IRAK4_R_0.htm',
#  'data/TIDE/tide_output/posC8_PRKAG3_3_A;PRKAG3_R_0.htm',
#  'data/TIDE/tide_output/posF7_PANK2_3_B;PANK2_R_0.htm',
#  'data/TIDE/tide_output/posB6_PIK3CB_2_B;PIK3CB_R_0.htm',
#  'data/TIDE/tide_output/posF1_PANK2_1_A;PANK2_R_0.htm',
#  'data/TIDE/tide_output/posA3_PRKAG1_1_B;PRKAG1_R_0.htm',
#  'data/TIDE/tide_output/posD1_PIK3C2A_1_A;PIK3C2A_R_0.htm',
#  'data/TIDE/tide_output/posH5_SBK2_2_B;SBK2_R_0.htm',
#  'data/TIDE/tide_output/posF4_PANK2_2_B;PANK2_R_0.htm',
#  'data/TIDE/tide_output/posG4_UCK1_2_B;UCK1_R_0.htm',
#  'data/TIDE/tide_output/posE8_MYO3A_3_A;MYO3A_R_0.htm',
#  'data/TIDE/tide_output/posD7_PIK3C2A_3_B;PIK3C2A_R_0.htm',
#  'data/TIDE/tide_output/posC6_IRAK4_2_A;IRAK4_R_0.htm',
#  'data/TIDE/tide_output/posG3_CHUK_1_B;CHUK_R_0.htm',
#  'data/TIDE/tide_output/posD4_PIK3C2A_2_A;PIK3C2A_R_0.htm',
#  'data/TIDE/tide_output/posD3_STK4_1_B;STK4_R_0.htm',
#  'data/TIDE/tide_output/posG2_UCK2_1_A;UCK2_R_0.htm',
#  'data/TIDE/tide_output/posC3_IRAK4_1_B;IRAK4_R_0.htm',
#  'data/TIDE/tide_output/posB9_PIK3CB_3_B;PIK3CB_R_0.htm',
#  'data/TIDE/tide_output/posH2_SBK2_1_A;SBK2_R_0.htm',
#  'data/TIDE/tide_output/posB2_PIK3CA_1_A;PIK3CA_R_0.htm',
#  'data/TIDE/tide_output/posC5_PRKAG3_2_B;PRKAG3_R_0.htm',
#  'data/TIDE/tide_output/posE2_MYO3A_1_B;MYO3A_R_0.htm',
#  'data/TIDE/tide_output/posA5_BUB1B_2_A;BUB1B_R_0.htm',
#  'data/TIDE/tide_output/posF5_TTK_2_A;TTK_R_0.htm',
#  'data/TIDE/tide_output/posF2_TTK_1_A;TTK_R_0.htm',
#  'data/TIDE/tide_output/posC8_PRKAG3_3_B;PRKAG3_R_0.htm',
#  'data/TIDE/tide_output/posB6_PIK3CB_2_A;PIK3CB_R_0.htm',
#  'data/TIDE/tide_output/posD2_STK3_1_A;STK3_R_0.htm',
#  'data/TIDE/tide_output/posE2_MYO3A_1_A;MYO3A_R_0.htm',
#  'data/TIDE/tide_output/posA5_BUB1B_2_B;BUB1B_R_0.htm',
#  'data/TIDE/tide_output/posH4_RET_2_A;RET_R_0.htm',
#  'data/TIDE/tide_output/posA4_RYK_2_A;RYK_R_0.htm',
#  'data/TIDE/tide_output/posG7_UCK1_3_A;UCK1_R_0.htm',
#  'data/TIDE/tide_output/posC6_IRAK4_2_B;IRAK4_R_0.htm',
#  'data/TIDE/tide_output/posA1_RYK_1_A;RYK_R_0.htm',
#  'data/TIDE/tide_output/posC3_IRAK4_1_A;IRAK4_R_0.htm',
#  'data/TIDE/tide_output/posH1_RET_1_A;RET_R_0.htm',
#  'data/TIDE/tide_output/posG1_UCK1_1_A;UCK1_R_0.htm',
#  'data/TIDE/tide_output/posA3_PRKAG1_1_A;PRKAG1_R_0.htm',
#  'data/TIDE/tide_output/posB3_PIK3CB_1_B;PIK3CB_R_0.htm',
#  'data/TIDE/tide_output/posE9_MYO3B_3_B;MYO3B_R_0.htm',
#  'data/TIDE/tide_output/posD3_STK4_1_A;STK4_R_0.htm',
#  'data/TIDE/tide_output/posG2_UCK2_1_B;UCK2_R_0.htm',
#  'data/TIDE/tide_output/posB8_PIK3CA_3_A;PIK3CA_R_0.htm',
#  'data/TIDE/tide_output/posG3_CHUK_1_A;CHUK_R_0.htm',
#  'data/TIDE/tide_output/posD7_PIK3C2A_3_A;PIK3C2A_R_0.htm',
#  'data/TIDE/tide_output/posD1_PIK3C2A_1_B;PIK3C2A_R_0.htm',
#  'data/TIDE/tide_output/posH2_SBK2_1_B;SBK2_R_0.htm',
#  'data/TIDE/tide_output/posE5_MYO3A_2_A;MYO3A_R_0.htm',
#  'data/TIDE/tide_output/posA2_BUB1B_1_B;BUB1B_R_0.htm',
#  'data/TIDE/tide_output/posA6_PRKAG1_2_B;PRKAG1_R_0.htm',
#  'data/TIDE/tide_output/posA7_RYK_3_A;RYK_R_0.htm',
#  'data/TIDE/tide_output/posH7_RET_3_A;RET_R_0.htm',
#  'data/TIDE/tide_output/posD2_STK3_1_B;STK3_R_0.htm',
#  'data/TIDE/tide_output/posA9_PRKAG1_3_A;PRKAG1_R_0.htm',
#  'data/TIDE/tide_output/posA2_BUB1B_1_A;BUB1B_R_0.htm',
#  'data/TIDE/tide_output/posG1_UCK1_1_B;UCK1_R_0.htm',
#  'data/TIDE/tide_output/posE9_MYO3B_3_A;MYO3B_R_0.htm',
#  'data/TIDE/tide_output/posF8_TTK_3_B;TTK_R_0.htm',
#  'data/TIDE/tide_output/posC2_PRKAG3_1_B;PRKAG3_R_0.htm',
#  'data/TIDE/tide_output/posB5_PIK3CA_2_A;PIK3CA_R_0.htm',
#  'data/TIDE/tide_output/posG7_UCK1_3_B;UCK1_R_0.htm',
#  'data/TIDE/tide_output/posB8_PIK3CA_3_B;PIK3CA_R_0.htm',
#  'data/TIDE/tide_output/posG8_UCK2_3_B;UCK2_R_0.htm',
#  'data/TIDE/tide_output/posD9_STK4_3_A;STK4_R_0.htm',
#  'data/TIDE/tide_output/posG9_CHUK_3_A;CHUK_R_0.htm',
#  'data/TIDE/tide_output/posG6_CHUK_2_B;CHUK_R_0.htm',
#  'data/TIDE/tide_output/posD5_STK3_2_A;STK3_R_0.htm',
#  'data/TIDE/tide_output/posB3_PIK3CB_1_A;PIK3CB_R_0.htm',
#  'data/TIDE/tide_output/posB7_CAMK1_3_B;CAMK1_R_0.htm',
#  'data/TIDE/tide_output/posF8_TTK_3_A;TTK_R_0.htm',
#  'data/TIDE/tide_output/posD6_STK4_2_B;STK4_R_0.htm',
#  'data/TIDE/tide_output/posA8_BUB1B_3_B;BUB1B_R_0.htm',
#  'data/TIDE/tide_output/posA6_PRKAG1_2_A;PRKAG1_R_0.htm',
#  'data/TIDE/tide_output/posB1_CAMK1_1_A;CAMK1_R_0.htm',
#  'data/TIDE/tide_output/posE3_MYO3B_1_B;MYO3B_R_0.htm',
#  'data/TIDE/tide_output/posH8_SBK2_3_B;SBK2_R_0.htm',
#  'data/TIDE/tide_output/posE6_MYO3B_2_A;MYO3B_R_0.htm',
#  'data/TIDE/tide_output/posB4_CAMK1_2_B;CAMK1_R_0.htm',
#  'data/TIDE/tide_output/posE3_MYO3B_1_A;MYO3B_R_0.htm',
#  'data/TIDE/tide_output/posB1_CAMK1_1_B;CAMK1_R_0.htm',
#  'data/TIDE/tide_output/posH7_RET_3_B;RET_R_0.htm',
#  'data/TIDE/tide_output/posA7_RYK_3_B;RYK_R_0.htm',
#  'data/TIDE/tide_output/posG5_UCK2_2_A;UCK2_R_0.htm',
#  'data/TIDE/tide_output/posA9_PRKAG1_3_B;PRKAG1_R_0.htm',
#  'data/TIDE/tide_output/posB4_CAMK1_2_A;CAMK1_R_0.htm',
#  'data/TIDE/tide_output/posE6_MYO3B_2_B;MYO3B_R_0.htm',
#  'data/TIDE/tide_output/posD8_STK3_3_B;STK3_R_0.htm',
#  'data/TIDE/tide_output/posD4_PIK3C2A_2_B;PIK3C2A_R_0.htm',
#  'data/TIDE/tide_output/posH5_SBK2_2_A;SBK2_R_0.htm',
#  'data/TIDE/tide_output/posG4_UCK1_2_A;UCK1_R_0.htm',
#  'data/TIDE/tide_output/posB5_PIK3CA_2_B;PIK3CA_R_0.htm',
#  'data/TIDE/tide_output/posC2_PRKAG3_1_A;PRKAG3_R_0.htm',
#  'data/TIDE/tide_output/posA8_BUB1B_3_A;BUB1B_R_0.htm',
#  'data/TIDE/tide_output/posB7_CAMK1_3_A;CAMK1_R_0.htm']

# %%
from shutil import copyfile

for file in glob.glob('data/TIDE/tide_output/*.htm'):
    copyfile(file, dst)
